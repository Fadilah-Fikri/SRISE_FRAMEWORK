# %%
import pandas as pd

df = pd.read_csv("../dataset/indonesia_earthquake.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nHead:")
print(df.head())

print("\nInfo:")
print(df.info())
# Out:
# Shape: (102515, 12)
#
# Columns:
# ['id', 'eventID', 'date', 'time', 'latitude', 'longitude', 'magnitude', 'mag_type', 'depth', 'phasecount', 'azimuth_gap', 'location']
#
# Head:
#    id      eventID       date     time  latitude   longitude  magnitude  \
# 0   0  bmg2008vkye  11/1/2008  31:25.1 -0.604440   98.895531   2.989742
# 1   1  bmg2008vlag  11/1/2008  34:29.7 -6.611860  129.387220   5.507549
# 2   2  bmg2008vlaj  11/1/2008  38:14.8 -3.650586  127.990680   3.539674
# 3   3  bmg2008vlbt  11/1/2008  20:05.9 -4.198925  128.097000   2.424314
# 4   4  bmg2008vlcd  11/1/2008  32:18.8 -4.091891  128.200470   2.410045
#
#   mag_type  depth  phasecount  azimuth_gap                     location
# 0      MLv     20         6.0    146.70738  Southern Sumatra, Indonesia
# 1       mb     30        62.0     45.46764                    Banda Sea
# 2      MLv      5         4.0    331.97404             Seram, Indonesia
# 3      MLv      5         5.0    326.37993                    Banda Sea
# ...
